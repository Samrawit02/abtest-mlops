# %% [markdown]
# # ADCampaign Data Exploration

# %% [markdown]
#    ## Data Understanding

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
import sys
import os
# %matplotlib inline
import seaborn as sns
import plotly.express as px

# %%
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from RWDataset import RWDataset
from clean_data import Clean_data
from visualization import *

# %%
df = pd.read_csv('../data/AdSmartABdata.csv')
df
# Out:
#                                 auction_id experiment        date  hour  \
# 0     0008ef63-77a7-448b-bd1e-075f42c55e39    exposed  2020-07-10     8
# 1     000eabc5-17ce-4137-8efe-44734d914446    exposed  2020-07-07    10
# 2     0016d14a-ae18-4a02-a204-6ba53b52f2ed    exposed  2020-07-05     2
# 3     00187412-2932-4542-a8ef-3633901c98d9    control  2020-07-03    15
# 4     001a7785-d3fe-4e11-a344-c8735acacc2c    control  2020-07-03    15
# ...                                    ...        ...         ...   ...
# 8072  ffea24ec-cec1-43fb-b1d1-8f93828c2be2    exposed  2020-07-05     7
# 8073  ffea3210-2c3e-426f-a77d-0aa72e73b20f    control  2020-07-03    15
# 8074  ffeaa0f1-1d72-4ba9-afb4-314b3b00a7c7    control  2020-07-04     9
# 8075  ffeeed62-3f7c-4a6e-8ba7-95d303d40969    exposed  2020-07-05    15
# 8076  fffbb9ff-568a-41a5-a0c3-6866592f80d8    control  2020-07-10    14
#
#              device_make  platform_os                browser  yes  no
# ...

# %%
df.isna().sum()
# Out:
# auction_id     0
# experiment     0
# date           0
# hour           0
# device_make    0
# platform_os    0
# browser        0
# yes            0
# no             0
# dtype: int64

# %%
for i in ["n/a", "na", "undefined"]:
    if i in df:
        print(f'{i} present')
    else:
        print('Absent')
# Out:
# Absent
# Absent
# Absent

# %% [markdown]
# This is used to determine whether there are cells in the dataset that contain the listed values which are same as having null values. If they wer present, we would have been prompted to fill them in appropriate ways

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8077 entries, 0 to 8076
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   auction_id   8077 non-null   object
#  1   experiment   8077 non-null   object
#  2   date         8077 non-null   object
#  3   hour         8077 non-null   int64
#  4   device_make  8077 non-null   object
#  5   platform_os  8077 non-null   int64
#  6   browser      8077 non-null   object
#  7   yes          8077 non-null   int64
#  8   no           8077 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 568.0+ KB

# %%
df.shape
# Out:
# (8077, 9)

# %%
df.describe()
# Out:
#               hour  platform_os          yes           no
# count  8077.000000  8077.000000  8077.000000  8077.000000
# mean     11.615080     5.947134     0.070818     0.083075
# std       5.734879     0.224333     0.256537     0.276013
# min       0.000000     5.000000     0.000000     0.000000
# 25%       7.000000     6.000000     0.000000     0.000000
# 50%      13.000000     6.000000     0.000000     0.000000
# 75%      15.000000     6.000000     0.000000     0.000000
# max      23.000000     7.000000     1.000000     1.000000

# %% [markdown]
# ## Missing Values

# %%
clean = Clean_data()

# %%
clean.percent_missing_values(df)
# Out:
# The SmartAd dataset contains 0.0 % missing values.

# %% [markdown]
# #### now let's us explore each columns of the data set

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# #### auction_id

# %%
auction_id_count = df['auction_id'].nunique()
auction_id_count
# Out:
# 8077

# %% [markdown]
# #### from the above output we can see that the the output is the same as the number of rows of the dataset , and this indicate that each auction id is unique

# %% [markdown]
# ### Experiments

# %%
experiment_count = df['experiment'].value_counts()
experiment_count
# Out:
# control    4071
# exposed    4006
# Name: experiment, dtype: int64

# %%
hist(experiment_count)

# %%
#Unique value counts of categorical variables and their plots

#Unique value counts of device_make
df['device_make'].count()
# Out:
# 8077

# %%
df['device_make'].value_counts().nlargest(10)
# Out:
# Generic Smartphone    4743
# iPhone                 433
# Samsung SM-G960F       203
# Samsung SM-G973F       154
# Samsung SM-G950F       148
# Samsung SM-G930F       100
# Samsung SM-G975F        97
# Samsung SM-A202F        88
# Samsung SM-A405FN       87
# Samsung SM-J330FN       69
# Name: device_make, dtype: int64

# %%
fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('device_make', fontsize=10)
ax.set_ylabel('Counts' , fontsize=10)
ax.set_title('Device make Total Counts', fontsize=10)
df['device_make'].value_counts()[:20].plot(ax=ax, kind='bar', color='orange')
# Out:
# <AxesSubplot:title={'center':'Device make Total Counts'}, xlabel='device_make', ylabel='Counts'>

# %% [markdown]
# ### from the above plot we mostly used device is Generic smart phone

# %%
#Unique value count for browser of the user

df['browser'].nunique()
# Out:
# 15

# %%
df['browser'].value_counts()
# Out:
# Chrome Mobile                 4554
# Chrome Mobile WebView         1489
# Samsung Internet               824
# Facebook                       764
# Mobile Safari                  337
# Chrome Mobile iOS               51
# Mobile Safari UI/WKWebView      44
# Chrome                           3
# Pinterest                        3
# Opera Mobile                     3
# Opera Mini                       1
# Edge Mobile                      1
# Android                          1
# Firefox Mobile                   1
# Puffin                           1
# Name: browser, dtype: int64

# %%
plot_univariate(df,x='browser', title='Unique value counts of the browser column')

# %%
#Unique value count for date

df['date'].nunique()
plot_univariate(df,'date', 'Unique value counts of dates data were collected ')

# %% [markdown]
# #### from the above plot we can see that the first day has highest number of vistors than the other days

# %%
#Unique value count for platform_os

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=10)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('device_make', fontsize=10)
ax.set_ylabel('Counts' , fontsize=10)
ax.set_title('Device make Total Counts', fontsize=10)
df['platform_os'].value_counts()[:20].plot(ax=ax, kind='bar', color='green')
# Out:
# <AxesSubplot:title={'center':'Device make Total Counts'}, xlabel='device_make', ylabel='Counts'>

# %% [markdown]
# The OS mostly used by smartads traffic is 6

# %%
#Unique value count for experiment
plot_univariate(df,'experiment', 'Unique value counts of experiment ')

# experiment

# %% [markdown]
# The graph determines the count of the exposed vs the control groups

# %%
# unique number of people who are aware of the company
counts_yes = df['yes'].value_counts()[1]
counts_yes
# Out:
# 572

# %%
# unique number of people who are not aware of the company
counts_no = df['no'].value_counts()[1]
counts_no
# Out:
# 671

# %%
#Number of people who did not respond to the questionnaire
df.shape[0] - (counts_yes + counts_no)
# Out:
# 6834

# %% [markdown]
# ## Bivariate Analysis

# %%
# data against experiment
bi_plot(df,'date','experiment','Date vs Experiment')

# %% [markdown]
# The graphs determine the total number of responses generated from both the control and exposed group within the specified days.
# There was a higher traffic on 2020-07-03 for the control group

# %%
bi_plot(df,'hour','experiment','Hour Experiment')

# %% [markdown]
# #### from the above plot we can see that control group was the most active at 15 hour

# %%
# data against device_make

bi_plot(df,'browser','experiment','Experiment against browser', 45)

# %% [markdown]
# The graph describes the number of the browser types used by both the control and exposed groups to give feedback.
# Chrome is the most commonly used browser for reaching smartad traffic

# %% [markdown]
# #### Experiment and OS

# %%
bi_plot(df,'platform_os','experiment','Experiment against platform_os')

# %% [markdown]
# ### Experiment and Yes

# %%
bi_plot(df,'yes','experiment','Experiment against yes')

# %% [markdown]
# ### Experiment and No

# %%
bi_plot(df,'no','experiment','Experiment against no')

# %%
corr = df.corr()
sns.heatmap(corr, annot=True)
plt.title('Heatmap of correlation for the numerical columns')
plt.show()
